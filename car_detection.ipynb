# %% [markdown]
# <a href="https://colab.research.google.com/github/darpankhanna/Car-Pedestrian-Detection/blob/main/car_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

# %%
car_cascade = cv2.CascadeClassifier('/content/cars.xml')
img = cv2.imread('/content/car1.jfif', 1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect cars
cars = car_cascade.detectMultiScale(gray, 1.1, 1)

# Draw border
ncars=0
for (x, y, w, h) in cars:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255), 1)
    ncars = ncars + 1

# Show image
plt.figure(figsize=(10,20))
plt.imshow(img)

# %%
img = cv2.imread('/content/Car.jpg', 1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cars = car_cascade.detectMultiScale(gray, 1.1, 1)
for (x, y, w, h) in cars:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2) 

plt.figure(figsize=(10,20))
plt.imshow(img)
